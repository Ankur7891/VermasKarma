# %%
pip install cv2
pip install deepface
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread("hollow_knight.jpeg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
from deepface import DeepFace
face_analysis = DeepFace.analyze(image_path, enforce_detection=True)
# Out:
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\Vishnu Narayanan\.deepface\weights\age_model_weights.h5
# 100%|███████████████████████████████████████████████████████████████████████████████| 539M/539M [00:37<00:00, 14.3MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\Vishnu Narayanan\.deepface\weights\gender_model_weights.h5
# 100%|███████████████████████████████████████████████████████████████████████████████| 537M/537M [00:32<00:00, 16.4MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/race_model_single_batch.h5
# To: C:\Users\Vishnu Narayanan\.deepface\weights\race_model_single_batch.h5
# ...

# %%
face_analysis
# Out:
# [{'emotion': {'angry': 98.27456474304199,
#    'disgust': 4.5338025326212283e-11,
#    'fear': 1.4027145311956701e-05,
#    'happy': 1.7253225669264793,
#    'sad': 5.310080837261921e-05,
#    'surprise': 2.6405633322262867e-10,
#    'neutral': 4.498928944940417e-05},
#   'dominant_emotion': 'angry',
#   'region': {'x': 492, 'y': 637, 'w': 66, 'h': 66},
#   'age': 27,
#   'gender': {'Woman': 2.2991767153143883, 'Man': 97.70082235336304},
#   'dominant_gender': 'Man',
#   'race': {'asian': 2.1351606926417763,
#    'indian': 1.3996667131582923,
#    'black': 0.10684307835805883,
#    'white': 66.83426897730047,
#    'middle eastern': 21.29192479204683,
#    'latino hispanic': 8.23213730645998},
#   'dominant_race': 'white'}]

# %%
emotion_scores= face_analysis[0].get('emotion')
largest_emotion=max(emotion_scores,key=emotion_scores.get)
largest_emotion_score=emotion_scores[largest_emotion]
print("Largest emotion :- ",largest_emotion)
print("Largest emotion score :- ",largest_emotion_score)
# Out:
# Largest emotion :-  angry
# Largest emotion score :-  98.27456474304199
